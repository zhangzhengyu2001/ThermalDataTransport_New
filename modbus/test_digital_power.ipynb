# %%
from digital_power import DigitalPowerController

dp = DigitalPowerController(port="COM6")

# %%
reg_v = dp.read_register()
print(reg_v)
print("Voltage: {} V".format(DigitalPowerController.register_to_voltage(reg_v[0], max_range_v=10.0)))
# Out:
# [500]
# Voltage: 1.0 V

# %%
print(dp.set_voltage(7.0,10.0))
# Out:
# 3500

# %%
dp.close()
